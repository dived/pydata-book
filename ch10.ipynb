# %% [markdown]
# # Data Aggregation and Group Operations

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## GroupBy Mechanics 分组机制

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.204708  1.393406
# 1    a  two  0.478943  0.092908
# 2    b  one -0.519439  0.281746
# 3    b  two -0.555730  0.769023
# 4    a  one  1.965781  1.246435

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped.mean()
# Out:
# key1
# a    0.746672
# b   -0.537585
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
# Out:
# key1  key2
# a     one     0.880536
#       two     0.478943
# b     one    -0.519439
#       two    -0.555730
# Name: data1, dtype: float64

# %%
# print(means.unstack().columns)
means.unstack()

# means
# Out:
# Index(['one', 'two'], dtype='object', name='key2')
# key2       one       two
# key1
# a     0.880536  0.478943
# b    -0.519439 -0.555730

# %%
df['data1']
# Out:
# 0   -0.204708
# 1    0.478943
# 2   -0.519439
# 3   -0.555730
# 4    1.965781
# Name: data1, dtype: float64

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
years = np.array([2005, 2005, 2006, 2005, 2006])
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005    0.478943
#             2006   -0.519439
# Ohio        2005   -0.380219
#             2006    1.965781
# Name: data1, dtype: float64

# %%
print(df.groupby('key1').mean())
df.groupby(['key1', 'key2']).mean()

# %%
df.groupby(['key1', 'key2']).size()

# %% [markdown]
# ### Iterating Over Groups 对分组进行迭代

# %%
for name, group in df.groupby('key1'):
    print(name)
    print(group)

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']):
    print((k1, k2))
    print(group)

# %%
print(df.groupby(['key1', 'key2']).size())
for (k1,k2), group in df.groupby(['key1', 'key2']):
    print(k1,k2)
    print(group)
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64
# a one
#   key1 key2     data1     data2
# 0    a  one -0.204708  1.393406
# 4    a  one  1.965781  1.246435
# a two
#   key1 key2     data1     data2
# 1    a  two  0.478943  0.092908
# b one
#   key1 key2     data1     data2
# 2    b  one -0.519439  0.281746
# b two
#   key1 key2    data1     data2
# 3    b  two -0.55573  0.769023

# %%
pieces = dict(list(df.groupby('key1')))
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one -0.519439  0.281746
# 3    b  two -0.555730  0.769023

# %%
# print(df.dtypes, type(df.dtypes), df.dtypes.keys())
grouped = df.groupby(df.dtypes, axis=1)

# %%
grouped = df.groupby(df.dtypes, axis=1)
print(df.groupby(df.dtypes, axis=1).size())
for dtype, group in grouped:
    print(dtype)
    print(group)
# Out:
# float64    2
# object     2
# dtype: int64
# float64
#       data1     data2
# 0 -0.204708  1.393406
# 1  0.478943  0.092908
# 2 -0.519439  0.281746
# 3 -0.555730  0.769023
# 4  1.965781  1.246435
# object
#   key1 key2
# 0    a  one
# 1    a  two
# 2    b  one
# 3    b  two
# 4    a  one

# %% [markdown]
# ### Selecting a Column or Subset of Columns 选取列或列的子集

# %% [markdown]
# #上面是语法糖
# df.groupby('key1')['data1']
# df.groupby('key1')[['data2']]

# %% [markdown]
# #这里是老实人
# df['data1'].groupby(df['key1'])
# df[['data2']].groupby(df['key1'])

# %%
print(df)
print(df.groupby('key1')['data1'].mean())
df.groupby('key1')[['data2','data1']].mean()
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.204708  1.393406
# 1    a  two  0.478943  0.092908
# 2    b  one -0.519439  0.281746
# 3    b  two -0.555730  0.769023
# 4    a  one  1.965781  1.246435
# key1
# a    0.746672
# b   -0.537585
# Name: data1, dtype: float64
#          data2     data1
# key1
# a     0.910916  0.746672
# b     0.525384 -0.537585

# %%
df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one   1.319920
#      two   0.092908
# b    one   0.281746
#      two   0.769023

# %%
s_grouped = df.groupby(['key1', 'key2'])['data2']
s_grouped
s_grouped.mean()
# Out:
# key1  key2
# a     one     1.319920
#       two     0.092908
# b     one     0.281746
#       two     0.769023
# Name: data2, dtype: float64

# %% [markdown]
# ### Grouping with Dicts and Series 通过字典或序列分组

# %%
people = pd.DataFrame(np.random.randn(5, 5),
                      columns=['a', 'b', 'c', 'd', 'e'],
                      index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])
# print(people)
people.iloc[2, [1, 2]] = np.nan
people.iloc[2:3, [1, 2]] = np.nan # Add a few NA values
people
# Out:
#                a         b         c         d         e
# Joe    -0.204708  0.478943 -0.519439 -0.555730  1.965781
# Steve   1.393406  0.092908  0.281746  0.769023  1.246435
# Wes     1.007189       NaN       NaN  0.228913  1.352917
# Jim     0.886429 -2.001637 -0.371843  1.669025 -0.438570
# Travis -0.539741  0.476985  3.248944 -1.021228 -0.577087

# %%
people.groupby??

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
           'd': 'blue', 'e': 'red', 'f' : 'orange'}
people_m = people.rename(columns={'a': 'red', 'b': 'red', 'c': 'blue',
           'd': 'blue', 'e': 'red', 'f' : 'orange'})
people_m
# Out:
#              red       red      blue      blue       red
# Joe     1.824875 -0.997518  0.850591 -0.131578  0.912414
# Steve   0.188211  2.169461 -0.114928  2.003697  0.029610
# Wes     0.795253       NaN       NaN  0.584970  0.152677
# Jim    -1.565657 -0.562540 -0.032664 -0.929006 -0.482573
# Travis -0.036264  1.095390  0.980928 -0.589488  1.581700

# %%
by_column = people.groupby(level=0, axis=1)
# by_column = people.groupby(mapping, axis=1)
by_column.sum()
# Out:
#             blue       red
# Joe     0.720225  1.705513
# Steve  -2.956703 -2.197664
# Wes     0.690002 -0.331066
# Jim    -1.647382 -0.902466
# Travis  1.250317 -0.095666

# %%
map_series = pd.Series(mapping)
print(map_series)
people.groupby(map_series, axis=1).count()
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %% [markdown]
# ### Grouping with Functions 根据函数分组

# %%
people
# Out:
#                a         b         c         d         e
# Joe    -0.204708  0.478943 -0.519439 -0.555730  1.965781
# Steve   1.393406  0.092908  0.281746  0.769023  1.246435
# Wes     1.007189       NaN       NaN  0.228913  1.352917
# Jim     0.886429 -2.001637 -0.371843  1.669025 -0.438570
# Travis -0.539741  0.476985  3.248944 -1.021228 -0.577087

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  1.688911 -1.522694 -0.891281  1.342208  2.880128
# 5  1.393406  0.092908  0.281746  0.769023  1.246435
# 6 -0.539741  0.476985  3.248944 -1.021228 -0.577087

# %%
key_list = ['one', 'one', 'one', 'two', 'two']
people.groupby([len, key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one -0.204708  0.478943 -0.519439 -0.555730  1.352917
#   two  0.886429 -2.001637 -0.371843  1.669025 -0.438570
# 5 one  1.393406  0.092908  0.281746  0.769023  1.246435
# 6 two -0.539741  0.476985  3.248944 -1.021228 -0.577087

# %% [markdown]
# ### Grouping by Index Levels 索引等级分组

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
                                    [1, 3, 5, 1, 3]],
                                    names=['cty', 'tenor'])
hier_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      0.124121  0.302614  0.523772  0.000940  1.343810
# 1     -0.713544 -0.831154 -2.370232 -1.860761 -0.860757
# 2      0.560145 -1.265934  0.119827 -1.063512  0.332883
# 3     -2.359419 -0.199543 -1.541996 -0.970736 -1.307030

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %% [markdown]
# ## Data Aggregation 数据聚合

# %%
# Out:
# Object `quantile` not found.

# %%
grouped['data1'].quantile

# %%
grouped['data1'].quantile

# %%
print(df)
grouped = df.groupby('key1')
print(list(grouped['data1']))
# print(grouped['data1'])
grouped['data1'].quantile(0.9)
#普通用法 np.quantile([array], q=0.25)
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.204708  1.393406
# 1    a  two  0.478943  0.092908
# 2    b  one -0.519439  0.281746
# 3    b  two -0.555730  0.769023
# 4    a  one  1.965781  1.246435
# [('a', 0   -0.204708
# 1    0.478943
# 4    1.965781
# Name: data1, dtype: float64), ('b', 2   -0.519439
# 3   -0.555730
# Name: data1, dtype: float64)]
# key1
# a    1.668413
# b   -0.523068
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()
grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     2.170488  1.300498
# b     0.036292  0.487276

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0  0.746672  1.109736 -0.204708  0.137118  0.478943  1.222362
# b      2.0 -0.537585  0.025662 -0.555730 -0.546657 -0.537585 -0.528512
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     1.965781   3.0  0.910916  0.712217  0.092908  0.669671  1.246435
# b    -0.519439   2.0  0.525384  0.344556  0.281746  0.403565  0.525384
#
#
#            75%       max
# key1
# a     1.319920  1.393406
# b     0.647203  0.769023

# %% [markdown]
# ### Column-Wise and Multiple Function Application 面向列的多函数应用

# %%
tips = pd.read_csv('examples/tips.csv')
# Add tip percentage of total bill
print(tips)
tips['tip_pct'] = tips['tip'] / tips['total_bill']
tips[:6]
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808
# ...

# %%
grouped = tips.groupby(['day', 'smoker'])

# %%
grouped_pct = grouped['tip_pct']
grouped_pct.agg('mean')
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg(['mean', 'std', peak_to_peak])
# Out:
#                  mean       std  peak_to_peak
# day  smoker
# Fri  No      0.151650  0.028123      0.067349
#      Yes     0.174783  0.051293      0.159925
# Sat  No      0.158048  0.039767      0.235193
#      Yes     0.147906  0.061375      0.290095
# Sun  No      0.160113  0.042347      0.193226
#      Yes     0.187250  0.154134      0.644685
# Thur No      0.160298  0.038774      0.193350
#      Yes     0.163863  0.039389      0.151240

# %%
grouped_pct.agg([('foo', 'mean'), ('bar', np.std)])

# %%
functions = ['count', 'mean', 'max']
result = grouped['tip_pct', 'total_bill'].agg(functions)
result

# %%
result['tip_pct']

# %%
ftuples = [('Durchschnitt', 'mean'), ('Abweichung', np.var)]
grouped['tip_pct', 'total_bill'].agg(ftuples)

# %%
#只有将多个函数应用到至少一列时，DataFrame才会拥有层次化的列。 
grouped.agg({'tip' : np.max, 'size' : 'sum'})
grouped.agg({'tip_pct' : ['min', 'max', 'mean', 'std'],
             'size' : 'sum'})
# Out:
#               tip_pct                               size
#                   min       max      mean       std  sum
# day  smoker
# Fri  No      0.120385  0.187735  0.151650  0.028123    9
#      Yes     0.103555  0.263480  0.174783  0.051293   31
# Sat  No      0.056797  0.291990  0.158048  0.039767  115
#      Yes     0.035638  0.325733  0.147906  0.061375  104
# Sun  No      0.059447  0.252672  0.160113  0.042347  167
#      Yes     0.065660  0.710345  0.187250  0.154134   49
# Thur No      0.072961  0.266312  0.160298  0.038774  112
#      Yes     0.090014  0.241255  0.163863  0.039389   40

# %%
#其实只要将函数用列表方式展示，就可以展示深层次的列
print(grouped.agg({'tip' : np.max, 'size' : 'sum'}))
grouped.agg({'tip' : np.max, 'size' : ['sum']})
# Out:
#                tip  size
# day  smoker
# Fri  No       3.50     9
#      Yes      4.73    31
# Sat  No       9.00   115
#      Yes     10.00   104
# Sun  No       6.00   167
#      Yes      6.50    49
# Thur No       6.70   112
#      Yes      5.00    40
#                tip size
#               amax  sum
# day  smoker
# Fri  No       3.50    9
#      Yes      4.73   31
# Sat  No       9.00  115
#      Yes     10.00  104
# Sun  No       6.00  167
#      Yes      6.50   49
# Thur No       6.70  112
#      Yes      5.00   40

# %% [markdown]
# ### Returning Aggregated Data Without Row Indexes
# ##就是将索引也一起以列展示成结果

# %%
tips.groupby(['day', 'smoker'], as_index=False).mean()
# Out:
#     day smoker  total_bill       tip      size   tip_pct
# 0   Fri     No   18.420000  2.812500  2.250000  0.151650
# 1   Fri    Yes   16.813333  2.714000  2.066667  0.174783
# 2   Sat     No   19.661778  3.102889  2.555556  0.158048
# 3   Sat    Yes   21.276667  2.875476  2.476190  0.147906
# 4   Sun     No   20.506667  3.167895  2.929825  0.160113
# 5   Sun    Yes   24.120000  3.516842  2.578947  0.187250
# 6  Thur     No   17.113111  2.673778  2.488889  0.160298
# 7  Thur    Yes   19.190588  3.030000  2.352941  0.163863

# %% [markdown]
# ## Apply: General split-apply-combine 一般拆分、应用、合并

# %%
def top(df, n=5, column='tip_pct'):
    return df.sort_values(by=column)[-n:]
top(tips, n=6)
# Out:
#      total_bill   tip smoker  day    time  size   tip_pct
# 109       14.31  4.00    Yes  Sat  Dinner     2  0.279525
# 183       23.17  6.50    Yes  Sun  Dinner     4  0.280535
# 232       11.61  3.39     No  Sat  Dinner     2  0.291990
# 67         3.07  1.00    Yes  Sat  Dinner     1  0.325733
# 178        9.60  4.00    Yes  Sun  Dinner     2  0.416667
# 172        7.25  5.15    Yes  Sun  Dinner     2  0.710345

# %%
tips.groupby('smoker').apply(top)

# %%
tips.groupby(['smoker', 'day']).apply(top, n=1, column='total_bill')

# %%
result = tips.groupby('smoker')['tip_pct'].describe()
result
result.unstack('smoker')

# %% [markdown]
# f = lambda x: x.describe()
# grouped.apply(f)

# %% [markdown]
# ### Suppressing the Group Keys 阻止分组键

# %%
tips.groupby('smoker', group_keys=False).apply(top)
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 88        24.71  5.85     No  Thur   Lunch     2  0.236746
# 185       20.69  5.00     No   Sun  Dinner     5  0.241663
# 51        10.29  2.60     No   Sun  Dinner     2  0.252672
# 149        7.51  2.00     No  Thur   Lunch     2  0.266312
# 232       11.61  3.39     No   Sat  Dinner     2  0.291990
# 109       14.31  4.00    Yes   Sat  Dinner     2  0.279525
# 183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
# 67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
# 178        9.60  4.00    Yes   Sun  Dinner     2  0.416667
# 172        7.25  5.15    Yes   Sun  Dinner     2  0.710345

# %% [markdown]
# ### Quantile and Bucket Analysis 分位数和桶分析

# %%
frame = pd.DataFrame({'data1': np.random.randn(1000),
                      'data2': np.random.randn(1000)})
quartiles = pd.cut(frame.data1, 4)
quartiles[:10]
# Out:
# 0     (0.489, 2.208]
# 1    (-2.956, -1.23]
# 2     (-1.23, 0.489]
# 3     (-1.23, 0.489]
# 4     (0.489, 2.208]
# 5     (0.489, 2.208]
# 6    (-2.956, -1.23]
# 7     (-1.23, 0.489]
# 8     (0.489, 2.208]
# 9     (-1.23, 0.489]
# Name: data1, dtype: category
# Categories (4, interval[float64]): [(-2.956, -1.23] < (-1.23, 0.489] < (0.489, 2.208] < (2.208, 3.928]]

# %%
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),
            'count': group.count(), 'mean': group.mean()}
grouped = frame.data2.groupby(quartiles)
grouped.apply(get_stats).unstack()
# Out:
#                       min       max  count      mean
# data1
# (-2.956, -1.23] -3.399312  1.670835   96.0 -0.063122
# (-1.23, 0.489]  -2.989741  3.260383  596.0 -0.003908
# (0.489, 2.208]  -3.745356  2.954439  297.0  0.092315
# (2.208, 3.928]  -1.929776  1.765640   11.0  0.030607

# %%
# Return quantile numbers
grouping = pd.qcut(frame.data1, 10, labels=False)
grouped = frame.data2.groupby(grouping)
grouped.apply(get_stats).unstack()
# Out:
#             min       max  count      mean
# data1
# 0     -3.399312  1.670835  100.0 -0.086107
# 1     -1.801179  2.628441  100.0  0.051974
# 2     -2.925113  2.527939  100.0 -0.073978
# 3     -2.315555  3.260383  100.0  0.114297
# 4     -2.047939  2.074345  100.0 -0.127181
# 5     -2.989741  2.184810  100.0  0.021461
# 6     -2.084231  2.458842  100.0 -0.038834
# 7     -3.056990  2.954439  100.0  0.003504
# 8     -3.745356  2.735527  100.0  0.129800
# 9     -2.064111  2.377020  100.0  0.198718

# %%
# g = frame[['data1', 'data2']].groupby(grouping)
# g.apply(get_stats)#.unstack()
# Out:
# data1
# 0    {'min': [-2.949343498142557, -3.39931181881308...
# 1    {'min': [-1.2114110666621245, -1.8011794269395...
# 2    {'min': [-0.8711876507017066, -2.9251127706125...
# 3    {'min': [-0.5625401880747255, -2.3155548894240...
# 4    {'min': [-0.30233487136961246, -2.047939266201...
# 5    {'min': [-0.011861601071082155, -2.98974098974...
# 6    {'min': [0.2354770194411183, -2.08423057597015...
# 7    {'min': [0.5036992883408409, -3.05698974134267...
# 8    {'min': [0.827282588613972, -3.745355877331111...
# 9    {'min': [1.29762248958513, -2.064110886446809]...
# dtype: object

# %% [markdown]
# ### Example: Filling Missing Values with Group-Specific Values  分组指定填充缺失值

# %%
s = pd.Series(np.random.randn(6))
s[::2] = np.nan
s
s.fillna(s.mean())

# %%
states = ['Ohio', 'New York', 'Vermont', 'Florida',
          'Oregon', 'Nevada', 'California', 'Idaho']
group_key = ['East'] * 4 + ['West'] * 4
data = pd.Series(np.random.randn(8), index=states)
data

# %%
data[['Vermont', 'Nevada', 'Idaho']] = np.nan
data
data.groupby(group_key).mean()

# %%
fill_mean = lambda g: g.fillna(g.mean())
data.groupby(group_key).apply(fill_mean)

# %%
fill_values = {'East': 0.5, 'West': -1}
fill_func = lambda g: g.fillna(fill_values[g.name])
data.groupby(group_key).apply(fill_func)

# %% [markdown]
# ### Example: Random Sampling and Permutation 随机采样和排列

# %%
# Hearts, Spades, Clubs, Diamonds
suits = ['H', 'S', 'C', 'D']
card_val = (list(range(1, 11)) + [10] * 3) * 4
base_names = ['A'] + list(range(2, 11)) + ['J', 'K', 'Q']
cards = []
for suit in ['H', 'S', 'C', 'D']:
    cards.extend(str(num) + suit for num in base_names)

deck = pd.Series(card_val, index=cards)

# %%
deck[:13]

# %%
def draw(deck, n=5):
    return deck.sample(n)
draw(deck)

# %%
get_suit = lambda card: card[-1] # last letter is suit
deck.groupby(get_suit).apply(draw, n=2)

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n=2)

# %% [markdown]
# ### Example: Group Weighted Average and Correlation 加权平均和关联系数

# %%
df = pd.DataFrame({'category': ['a', 'a', 'a', 'a',
                                'b', 'b', 'b', 'b'],
                   'data': np.random.randn(8),
                   'weights': np.random.rand(8)})
df
# Out:
#   category      data   weights
# 0        a -1.065343  0.532409
# 1        a  0.276356  0.340703
# 2        a  1.680135  0.564676
# 3        a -0.679335  0.593408
# 4        b -0.129697  0.671732
# 5        b -1.930931  0.219819
# 6        b -0.607638  0.177322
# 7        b -0.195258  0.721681

# %%
grouped = df.groupby('category')
get_wavg = lambda g: np.average(g['data'], weights=g['weights'])
grouped.apply(get_wavg)
# Out:
# category
# a    0.035726
# b   -0.424583
# dtype: float64

# %%
close_px = pd.read_csv('examples/stock_px_2.csv', parse_dates=True,
                       index_col=0)
close_px.info()
close_px[-4:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB
#               AAPL   MSFT    XOM      SPX
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58

# %%
spx_corr = lambda x: x.corrwith(x['SPX'])

# %%
rets = close_px.pct_change().dropna()
rets
# Out:
#                 AAPL      MSFT       XOM       SPX
# 2003-01-03  0.006757  0.001421  0.000684 -0.000484
# 2003-01-06  0.000000  0.017975  0.024624  0.022474
# 2003-01-07 -0.002685  0.019052 -0.033712 -0.006545
# 2003-01-08 -0.020188 -0.028272 -0.004145 -0.014086
# 2003-01-09  0.008242  0.029094  0.021159  0.019386
# ...              ...       ...       ...       ...
# 2011-10-10  0.051406  0.026286  0.036977  0.034125
# 2011-10-11  0.029526  0.002227 -0.000131  0.000544
# 2011-10-12  0.004747 -0.001481  0.011669  0.009795
# 2011-10-13  0.015515  0.008160 -0.010238 -0.002974
# 2011-10-14  0.033225  0.003311  0.022784  0.017380
#
# [2213 rows x 4 columns]

# %%
get_year = lambda x: x.year
by_year = rets.groupby(get_year)
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
by_year.apply(lambda g: g['AAPL'].corr(g['MSFT']))
# Out:
# 2003    0.480868
# 2004    0.259024
# 2005    0.300093
# 2006    0.161735
# 2007    0.417738
# 2008    0.611901
# 2009    0.432738
# 2010    0.571946
# 2011    0.581987
# dtype: float64

# %% [markdown]
# ### Example: Group-Wise Linear Regression

# %%
import statsmodels.api as sm
def regress(data, yvar, xvars):
    Y = data[yvar]
    X = data[xvars]
    X['intercept'] = 1.
    result = sm.OLS(Y, X).fit()
    return result.params

# %%
by_year.apply(regress, 'AAPL', ['SPX'])

# %% [markdown]
# ## Pivot Tables and Cross-Tabulation 透视图和交叉表

# %%
tips.pivot_table(index=['day', 'smoker'])
# Out:
#                  size       tip   tip_pct  total_bill
# day  smoker
# Fri  No      2.250000  2.812500  0.151650   18.420000
#      Yes     2.066667  2.714000  0.174783   16.813333
# Sat  No      2.555556  3.102889  0.158048   19.661778
#      Yes     2.476190  2.875476  0.147906   21.276667
# Sun  No      2.929825  3.167895  0.160113   20.506667
#      Yes     2.578947  3.516842  0.187250   24.120000
# Thur No      2.488889  2.673778  0.160298   17.113111
#      Yes     2.352941  3.030000  0.163863   19.190588

# %%
tips.pivot_table(['tip_pct', 'size'], index=['time', 'day'],
                 columns='smoker')
# Out:
#                  size             tip_pct
# smoker             No       Yes        No       Yes
# time   day
# Dinner Fri   2.000000  2.222222  0.139622  0.165347
#        Sat   2.555556  2.476190  0.158048  0.147906
#        Sun   2.929825  2.578947  0.160113  0.187250
#        Thur  2.000000       NaN  0.159744       NaN
# Lunch  Fri   3.000000  1.833333  0.187735  0.188937
#        Thur  2.500000  2.352941  0.160311  0.163863

# %%
tips.pivot_table(['tip_pct', 'size'], index=['time', 'day'],
                 columns='smoker', margins=True)
# Out:
#                  size                       tip_pct
# smoker             No       Yes       All        No       Yes       All
# time   day
# Dinner Fri   2.000000  2.222222  2.166667  0.139622  0.165347  0.158916
#        Sat   2.555556  2.476190  2.517241  0.158048  0.147906  0.153152
#        Sun   2.929825  2.578947  2.842105  0.160113  0.187250  0.166897
#        Thur  2.000000       NaN  2.000000  0.159744       NaN  0.159744
# Lunch  Fri   3.000000  1.833333  2.000000  0.187735  0.188937  0.188765
#        Thur  2.500000  2.352941  2.459016  0.160311  0.163863  0.161301
# All          2.668874  2.408602  2.569672  0.159328  0.163196  0.160803

# %%
tips.pivot_table('tip_pct', index=['time', 'smoker'], columns='day',
                 aggfunc=len, margins=True)
# Out:
# day             Fri   Sat   Sun  Thur    All
# time   smoker
# Dinner No       3.0  45.0  57.0   1.0  106.0
#        Yes      9.0  42.0  19.0   NaN   70.0
# Lunch  No       1.0   NaN   NaN  44.0   45.0
#        Yes      6.0   NaN   NaN  17.0   23.0
# All            19.0  87.0  76.0  62.0  244.0

# %%
tips.pivot_table(['tip_pct'], index=['time', 'size', 'smoker'],
                 columns='day', aggfunc='mean', fill_value=0) #这里用列表参数 列名就变成2层了
# Out:
#                      tip_pct
# day                      Fri       Sat       Sun      Thur
# time   size smoker
# Dinner 1    No      0.000000  0.137931  0.000000  0.000000
#             Yes     0.000000  0.325733  0.000000  0.000000
#        2    No      0.139622  0.162705  0.168859  0.159744
#             Yes     0.171297  0.148668  0.207893  0.000000
#        3    No      0.000000  0.154661  0.152663  0.000000
# ...                      ...       ...       ...       ...
# Lunch  3    Yes     0.000000  0.000000  0.000000  0.204952
#        4    No      0.000000  0.000000  0.000000  0.138919
#             Yes     0.000000  0.000000  0.000000  0.155410
#        5    No      0.000000  0.000000  0.000000  0.121389
#        6    No      0.000000  0.000000  0.000000  0.173706
#
# [21 rows x 4 columns]

# %% [markdown]
# ### Cross-Tabulations: Crosstab  交叉表 计算分组频率

# %%
from io import StringIO
data = """\
Sample  Nationality  Handedness
1   USA  Right-handed
2   Japan    Left-handed
3   USA  Right-handed
4   Japan    Right-handed
5   Japan    Left-handed
6   Japan    Right-handed
7   USA  Right-handed
8   USA  Left-handed
9   Japan    Right-handed
10  USA  Right-handed"""
data = pd.read_table(StringIO(data), sep='\s+')

# %%
data
# Out:
#    Sample Nationality    Handedness
# 0       1         USA  Right-handed
# 1       2       Japan   Left-handed
# 2       3         USA  Right-handed
# 3       4       Japan  Right-handed
# 4       5       Japan   Left-handed
# 5       6       Japan  Right-handed
# 6       7         USA  Right-handed
# 7       8         USA   Left-handed
# 8       9       Japan  Right-handed
# 9      10         USA  Right-handed

# %%
pd.crosstab(data.Nationality, data.Handedness, margins=True)
# Out:
# Handedness   Left-handed  Right-handed  All
# Nationality
# Japan                  2             3    5
# USA                    1             4    5
# All                    3             7   10

# %%
pd.crosstab([tips.time, tips.day], tips.smoker, margins=True)
# Out:
# smoker        No  Yes  All
# time   day
# Dinner Fri     3    9   12
#        Sat    45   42   87
#        Sun    57   19   76
#        Thur    1    0    1
# Lunch  Fri     1    6    7
#        Thur   44   17   61
# All          151   93  244

# %%
pd.crosstab([tips['time'], tips['day']], tips['smoker'], margins=True)
# Out:
# smoker        No  Yes  All
# time   day
# Dinner Fri     3    9   12
#        Sat    45   42   87
#        Sun    57   19   76
#        Thur    1    0    1
# Lunch  Fri     1    6    7
#        Thur   44   17   61
# All          151   93  244

# %%
pd.options.display.max_rows = PREVIOUS_MAX_ROWS

# %% [markdown]
# ## Conclusion
