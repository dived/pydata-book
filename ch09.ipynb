# %% [markdown]
# # Plotting and Visualization

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# %matplotlib notebook

# %% [markdown]
# ## A Brief matplotlib API Primer

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.arange(10)
data
plt.plot(data)

# %% [markdown]
# ### Figures and Subplots

# %%
fig = plt.figure()
ax1 = fig.add_subplot(5, 5, 1)
ax7 = fig.add_subplot(5, 5, 7)
ax13 = fig.add_subplot(5, 5, 13)
ax19 = fig.add_subplot(5, 5, 19)
ax25 = fig.add_subplot(5, 5, 25)
_ = ax19.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax13.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
# plt.show()
# plt.plot(np.random.randn(50).cumsum(), 'k--')

# %% [markdown]
# fig = plt.figure()
# ax1 = fig.add_subplot(2, 2, 1)
# ax2 = fig.add_subplot(2, 2, 2)
# ax3 = fig.add_subplot(2, 2, 3)

# %%
# plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
plt.close('all')

# %%
fig, axes = plt.subplots(3, 3)
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)

# %% [markdown]
# #### Adjusting the spacing around subplots

# %% [markdown]
# subplots_adjust(left=None, bottom=None, right=None, top=None,
#                 wspace=None, hspace=None)

# %% [markdown]
# fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
# for i in range(2):
#     for j in range(2):
#         axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
# plt.subplots_adjust(wspace=0, hspace=0)

# %%
# fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
# for i in range(2):
#     for j in range(2):
#         axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
# plt.subplots_adjust(wspace=0, hspace=0)
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=1.0 )
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Colors, Markers, and Line Styles

# %% [markdown]
# ax.plot(x, y, 'g--')
# ax.plot(x, y, 'g--')

# %% [markdown]
# ax.plot(x, y, linestyle='--', color='g')

# %%
plt.figure()

# %%
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'ko--')

# %%
# plt.plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %% [markdown]
# plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
plt.close('all')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')

plt.legend(loc='best')

# %%
plt.plot(data,label='test')
plt.legend(loc=0)

# %% [markdown]
# ### Ticks, Labels, and Legends

# %% [markdown]
# #### Setting the title, axis labels, ticks, and ticklabels

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_title('My first matplotlib plot')
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
# ax.set_xticklabels(rotation=30, fontsize='small')
# labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
#                             (rotation=30, fontsize='small')
labels = ax.set_xticklabels([0, 250, 500, 750, 1000],
                            rotation=30, fontsize='small')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %% [markdown]
# props = {
#     'title': 'My first matplotlib plot',
#     'xlabel': 'Stages'
# }
# ax.set(**props)

# %% [markdown]
# #### Adding legends

# %%
from numpy.random import randn
# fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
# ax.plot(randn(1000).cumsum(), 'k', label='one')
# ax.plot(randn(1000).cumsum(), 'k--', label='two')
# ax.plot(randn(1000).cumsum(), 'k.', label='three')
# ax.legend(loc='best')
plt.plot(randn(1000).cumsum(), 'k', label='one')
plt.plot(randn(1000).cumsum(), 'k--', label='two')
plt.plot(randn(1000).cumsum(), 'k.', label='three')
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot(np.random.randn(1000).cumsum(), 'k', label='k')
ax.plot(np.random.randn(1000).cumsum(), 'k.', label='k.')
ax.plot(np.random.randn(1000).cumsum(), 'k--', label='k--')
ax.legend()

# %% [markdown]
# ### Annotations and Drawing on a Subplot

# %% [markdown]
# ax.text(x, y, 'Hello world!',
#         family='monospace', fontsize=10)

# %%
fig, ax = plt.subplots(1,1)
data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
# data.head()
spx = data['SPX']
# ax.plot(spx, 'k-')
spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]
for date, label in crisis_data:
    ax.annotate(label, 
                xy=(date, spx.asof(date) + 75),
               xytext=(date, spx.asof(date) + 225),
               arrowprops = dict(facecolor='black', headwidth=4, width=2, headlength=4),
                horizontalalignment='left', verticalalignment='top'
               )
ax.set_xlim(['1/1/2007', '1/1/2011'])
# ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600,1800])
ax.set_title("Important dates in  2008 financial crisis")
# Out:
# Text(0.5, 1.0, 'Important dates in  2008 financial crisis')

# %%
fig, ax = plt.subplots(1,1)
data = pd.read_csv('examples/spx.csv')#, index_col=0, parse_dates=True)
data.head()
# spx = data['SPX']
# spx.plot(ax=ax, style='k-')
# Out:
#                   Date     SPX
# 0  1990-02-01 00:00:00  328.79
# 1  1990-02-02 00:00:00  330.92
# 2  1990-02-05 00:00:00  331.85
# 3  1990-02-06 00:00:00  329.66
# 4  1990-02-07 00:00:00  333.75

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %%
ax.set_title('Important dates in the 2008–2009 financial crisis')

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
#
# rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
# circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
# pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
#                    color='g', alpha=0.5)
#
# ax.add_patch(rect)
# ax.add_patch(circ)
# ax.add_patch(pgon)

# %%
fig = plt.figure(figsize=(12, 6)); ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.6), 0.4, 0.15, color='k', alpha=0.3, label='Rectangle')
circ = plt.Circle((0.7, 0.4), 0.15, color='b', alpha=0.3, label='Circle')
pgon = plt.Polygon([[0.25, 0.25],[0.34, 0.23] ,[0.35, 0.4], [0.2, 0.6], ],
                   color='g', alpha=0.5, label='pgon')
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
# plt.legend()
plt.savefig('figpath.svg')
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Saving Plots to File

# %% [markdown]
# plt.savefig('figpath.svg')

# %% [markdown]
# plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# from io import BytesIO
# buffer = BytesIO()
# plt.savefig(buffer)
# plot_data = buffer.getvalue()

# %% [markdown]
# ### matplotlib Configuration

# %% [markdown]
# plt.rc('figure', figsize=(10, 10))

# %% [markdown]
# font_options = {'family' : 'monospace',
#                 'weight' : 'bold',
#                 'size'   : 'small'}
# plt.rc('font', **font_options)

# %% [markdown]
# ## Plotting with pandas and seaborn

# %% [markdown]
# ### Line Plots

# %%
plt.close('all')

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
print(s)
s.plot()
# Out:
# 0    -0.606437
# 10    0.401753
# 20   -0.866196
# 30    0.406139
# 40    0.614655
# 50    0.318565
# 60    0.686891
# 70    2.447082
# 80    3.367868
# 90    4.173325
# dtype: float64
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar Plots

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
np.random.seed(12348)

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
print(df)
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure()

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
plt.close('all')

# %%
tips = pd.read_csv('examples/tips.csv')
# print(tips.head())
party_counts = pd.crosstab(tips['day'], tips['size'])
print(party_counts)
# Not many 1- and 6-person parties
party_counts = party_counts.loc[:, 2:5]
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
# Normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(1), axis=0)
# print(party_counts.sum(1))
# print(party_pcts)
party_pcts.plot.bar()

# %%
plt.close('all')

# %%
import seaborn as sns
# print(tips)
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
print(tips.head())
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')
# sns.set(style="whitegrid")
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
plt.close('all')

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
plt.close('all')

# %%
sns.set(style="whitegrid")

# %% [markdown]
# ### Histograms and Density Plots

# %%
plt.figure()

# %%
tips['tip_pct'].plot.hist(bins=5) #bins  表示把X轴分成5个箱子的距离
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure()

# %%
tips['tip_pct'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure()

# %%
np.random.normal(10, 2, size=200)
# Out:
# array([ 6.9862,  6.1337, 11.3996,  8.3484, 11.8619,  8.2445,  9.4096,
#         8.9648,  6.8758,  8.1608, 11.365 ,  8.6131,  7.4738,  9.507 ,
#         7.756 , 12.4884, 10.9957, 12.0491, 11.6548, 12.2111,  8.1247,
#        11.9032,  8.7922,  8.8976, 13.5303, 10.3488, 10.8477,  8.7001,
#        10.5803,  8.765 ,  6.2896,  8.0917,  6.3565, 14.2812,  8.2711,
#        11.4098,  8.3854, 11.2773,  9.8988,  6.2808, 13.1796,  9.4282,
#        13.8363, 10.3238, 12.0346, 10.5465,  7.9693, 12.8813,  9.5535,
#         9.9954, 10.857 , 14.1362, 10.849 , 11.1061,  9.501 ,  9.7902,
#         8.3961, 10.239 , 11.0279, 10.8751,  8.7233,  7.7273,  4.1398,
#         8.2058,  9.9305,  8.3626, 12.2423,  8.7476,  7.9308,  5.0714,
#        10.3805,  7.7629, 10.0374,  8.5982,  9.9678, 11.0746,  8.5311,
#         8.2755, 11.4245,  8.1155, 11.4447,  7.628 ,  7.448 ,  6.9496,
#        10.6494,  9.2886, 10.6675,  8.5438, 12.113 ,  8.6809, 10.8267,
# ...

# %%
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(comp2, bins=100, color='k')
# Out:
# d:\python38\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Scatter or Point Plots

# %%
macro = pd.read_csv('examples/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
trans_data[-5:]

# %%
plt.figure()

# %%
sns.regplot('m1', 'unemp', data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})

# %% [markdown]
# ### Facet Grids and Categorical Data

# %%
sns.factorplot(x='day', y='tip_pct', hue='time', col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1])

# %%
sns.factorplot(x='day', y='tip_pct', row='time',
               col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1])

# %%
sns.factorplot(x='tip_pct', y='day', kind='box',
               data=tips[tips.tip_pct < 0.5])

# %% [markdown]
# ## Other Python Visualization Tools

# %%
pd.options.display.max_rows = PREVIOUS_MAX_ROWS

# %% [markdown]
# ## Conclusion
